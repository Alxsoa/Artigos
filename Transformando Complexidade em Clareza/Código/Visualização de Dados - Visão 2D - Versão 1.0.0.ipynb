# %% [markdown]
# ### **Bibliotecas Necessárias**

# %%
import numpy as np
import pandas as pd
import plotly
import plotly.express as px

# %% [markdown]
# ### **Definições Gerais**

# %%
DIR_RAIZ = "/home/asoares/Insync/alexandre.asoares@gmail.com/OneDrive/Atividades/LocalCases/Desenvolvimento/Visualização de Dados/Dataset/"

# %% [markdown]
# ### **Leitura da Base de Dados**

# %%
dfHousing=pd.read_csv(DIR_RAIZ + "Housing.csv", low_memory=False)

# %%
dfHousing
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# ### **Apresentação dos Dados em 2D**

# %%
Figura = px.scatter (
                        dfHousing,
                        "area",
                        "price",
                        labels = {
                                    "area": "<b>Área</b>",
                                    "price": "<b>Preço</b>"
                                 },

                        title="<b>Área x Preço</b>", 
                        width=800, 
                        height=600
                    )


Figura.show ()
